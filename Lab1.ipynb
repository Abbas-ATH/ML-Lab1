# %%
# Machine Learning Lab 1

## Student Name:
Abbas Aziz

## Description:
This lab demonstrates the process of setting up GitHub, creating a repository, cloning it using GitHub Desktop, creating a Jupyter Notebook in VS Code, and pushing the changes to GitHub.

# %%
## Steps I Followed:

1. Created a GitHub account.
2. Created a new repository named ML-Lab1.
3. Cloned the repository using GitHub Desktop.
4. Opened the project in Visual Studio Code.
5. Created a Jupyter Notebook file (Lab1.ipynb).
6. Selected the Python kernel.
7. Ran a simple Python test code.
8. Committed and pushed the notebook to GitHub.
